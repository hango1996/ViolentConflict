# %% [markdown]
# This notebook examines the results of the initial clustering.

# %%
# Allow imports from `..`
import os
import sys

module_path = os.path.abspath("..")
if module_path not in sys.path:
   sys.path.append(module_path)

# %%
from src.acled import read_acled
from src.utils import *

# %%
import pickle

import geopandas
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import sklearn as skl
import sklearn.cluster 
from sklearn.preprocessing import StandardScaler

# %%
res_na = read_acled("/Users/kandel/Desktop/Project/Rfiles/res_na.csv")
res_na = reproject_xy(res_na)
res_na.head()
# Out:
#    Unnamed: 0  data_id  cluster_label  iso event_id_cnty  event_id_no_cnty  \
# 0           1  4554831             43  788       TUN4978              4978
# 1           2  4554832             43  788       TUN4979              4979
# 2           3  4555026             43  788       TUN4975              4975
# 3           4  4555339             43  788       TUN4970              4970
# 4           5  4555341             43  788       TUN4972              4972
#
#   event_date  year  time_precision event_type  ... event_ctr_actor1_30  \
# 0 2019-03-09  2019               1   Protests  ...                 173
# 1 2019-03-09  2019               1   Protests  ...                 173
# 2 2019-03-08  2019               1   Protests  ...                 161
# 3 2019-03-07  2019               1   Protests  ...                 162
# 4 2019-03-07  2019               1   Protests  ...                 162
#
#   fatality_sum_actor1_.30 fatality_sum_actor1_30  event_ctr_actor1_inter_.30  \
# ...

# %%
matplotlib.rcParams['figure.figsize'] = [20, 15]

# %%
res_na.plot(column = "cluster_label", markersize = 20, cmap = "Dark2")
# Out:
# <AxesSubplot:>

# %%
#na_imp = read_acled('/Users/kandel/Desktop/Project/Rfiles/na_imp2.csv')
#na_imp = reproject_xy(na_imp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/1w/642jc4zj5nj3t1wvns_bm6h87hrh_5/T/ipykernel_11250/879587548.py in <module>
# ----> 1 na_imp = read_acled('/Users/kandel/Desktop/Project/Rfiles/na_imp2.csv')
#       2 na_imp = reproject_xy(na_imp)
#
# ~/Desktop/Project/2022_shenoy_conflict-main/src/acled.py in read_acled(path, lowercase_actors, crs)
#      77     # Strip all of the text columns.
#      78     is_str = region.applymap(lambda x: pd.isna(x) or isinstance(x, str)).all(0)
# ---> 79     region.loc[:, is_str] = region.loc[:, is_str].apply(
#      80         lambda x: x.str.strip())
#      81
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
# ...
