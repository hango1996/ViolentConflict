# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import importlib
import utils
importlib.reload(utils)

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
data_cluster = pd.read_csv('../data/clustering_Northern_Africa.csv')
data_feat    = pd.read_csv('../data/data_feat_stage3.csv')
data_cluster = data_cluster[['data_id', 'cluster_label']]

# %%
data_cluster = utils.ConstructCluster(data_feat, data_cluster)

# %%
utils.ClusterPctChange(data_cluster)
# Out:
#                                cluster_label           -30            30  \
# feature
# event_ctr                 max           91.0    375.586957    550.413043
#                           min           88.0   2787.582609   2409.495652
# event_ctr_actor1          max           61.0     11.424242     25.121212
#                           min           36.0     55.010989     23.714286
# event_ctr_actor1_inter    max           61.0      5.787879     15.363636
#                           min           36.0     35.758242     13.901099
# event_ctr_admin1          max           88.0    115.469565    273.139130
#                           min           89.0     78.242857     43.114286
# event_ctr_admin2          max           88.0     72.982609    152.356522
#                           min           95.0     17.595960      6.484848
# fatality_sum              max           91.0   5474.326087  38363.847826
#                           min           69.0  27530.500000  12704.500000
# ...

# %% [markdown]
# ### Level1: event counts

# %%
utils.ClusterDisplay('event_ctr_-30', data_cluster)

# %%
utils.ClusterDisplay('event_ctr_30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_-30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_30', data_cluster)

# %%
utils.ClusterDisplay('actor1_nunique_-30', data_cluster)

# %% [markdown]
# ### Level2: event counts admin1

# %%
utils.ClusterDisplay('event_ctr_admin1_-30', data_cluster)

# %%
utils.ClusterDisplay('event_ctr_admin1_30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_admin1_-30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_admin1_30', data_cluster)

# %%
utils.ClusterDisplay('actor1_nunique_admin1_-30', data_cluster)

# %% [markdown]
# ### Level3: event counts admin2

# %%
utils.ClusterDisplay('event_ctr_admin2_-30', data_cluster)

# %%
utils.ClusterDisplay('event_ctr_admin2_30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_admin2_-30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_admin2_30', data_cluster)

# %%
utils.ClusterDisplay('actor1_nunique_admin2_-30', data_cluster)

# %% [markdown]
# ### Level4: actor1

# %%
utils.ClusterDisplay('event_ctr_actor1_-30', data_cluster)

# %%
utils.ClusterDisplay('event_ctr_actor1_30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_actor1_-30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_actor1_30', data_cluster)

# %% [markdown]
# ### Level5: actor1 & interaction

# %%
utils.ClusterDisplay('event_ctr_actor1_inter_-30', data_cluster)

# %%
utils.ClusterDisplay('event_ctr_actor1_inter_30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_actor1_inter_-30', data_cluster)

# %%
utils.ClusterDisplay('fatality_sum_actor1_inter_30', data_cluster)
