# %%
# Allow imports from `..`
import os
import sys

module_path = os.path.abspath("..")
if module_path not in sys.path:
   sys.path.append(module_path)

# %%
from src.acled import read_acled
from src.utils import *

# %%
import pickle

import geopandas
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import sklearn as skl
import sklearn.cluster 
from sklearn.preprocessing import StandardScaler

# %%
res_wa = read_acled("/Users/kandel/Desktop/Project/Rfiles/res_wa.csv")
res_wa = reproject_xy(res_wa)
res_wa.head()
# Out:
#    Unnamed: 0  data_id  cluster_label  iso event_id_cnty  event_id_no_cnty  \
# 0           1  4554798             80  566      NIG14152             14152
# 1           2  4554799             10  566      NIG14153             14153
# 2           3  4554802             23  566      NIG14156             14156
# 3           4  4554803             58  566      NIG14157             14157
# 4           5  4554808             63  566      NIG14162             14162
#
#   event_date  year  time_precision                  event_type  ...  \
# 0 2019-03-09  2019               1  Violence against civilians  ...
# 1 2019-03-09  2019               1  Violence against civilians  ...
# 2 2019-03-09  2019               1                     Battles  ...
# 3 2019-03-09  2019               1                     Battles  ...
# 4 2019-03-09  2019               1  Violence against civilians  ...
#
#   event_ctr_actor1_30 fatality_sum_actor1_.30 fatality_sum_actor1_30  \
# ...

# %%
matplotlib.rcParams['figure.figsize'] = [20, 20]

# %%
res_wa.plot(column = "cluster_label", markersize = 20, cmap = "Dark2")
# Out:
# <AxesSubplot:>

# %%
wa_imp = read_acled('/Users/kandel/Desktop/Project/Rfiles/res_wa_imp.csv')
wa_imp = reproject_xy(wa_imp)

# %%
matplotlib.rcParams['figure.figsize'] = [20, 15]

# %%
wa_imp.plot(column = "cluster_label", markersize = 20, cmap = "Dark2")
# Out:
# <AxesSubplot:>
